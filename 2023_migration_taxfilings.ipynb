# %%
import pandas as pd

# %%
pd.read_csv("data/countyinflow1920.csv")
# Out:
#        y2_statefips  y2_countyfips  y1_statefips  y1_countyfips y1_state  \
# 0                 1              1            96              0       AL
# 1                 1              1            97              0       AL
# 2                 1              1            97              1       AL
# 3                 1              1            97              3       AL
# 4                 1              1            98              0       AL
# ...             ...            ...           ...            ...      ...
# 87547            56             45            59              0       DS
# 87548            56             45            59              1       DS
# 87549            56             45            59              3       DS
# 87550            56             45            59              5       DS
# 87551            56             45            59              7       DS
#
#                                         y1_countyname    n1    n2     agi
# ...
